# %% [markdown]
# # Handelling Missing Values : Deleting/Ignoring Missing Valued Rows

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading datasets
df = pd.read_csv("D:\\SAYAN SRK\\Datasets\\house-prices-advanced-regression-techniques\\train.csv")

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.head(6)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %% [raw]
# As it is shown above that the dataset haven't loaded with all 81 columns..
# so we have to use set_option() method of pandas...

# %%
# Setting datasets with maximum rows and columns..
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
df.head(6)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
# ...

# %% [markdown]
# #### As it is clear from the above dataset that the it contains many NULL valus or NaN values..So, we have to see how many NaN values it contains, and what is the percentage of NaN values in each column,... And We are gonna drop those columns with larger percentage of missing values..

# %%
# Lets see how many numbers of missing values, Each column of the dataset contains.. 
df.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %% [markdown]
# ### Lets visualize the current condition of the dataset..

# %%
# Data Visualization is needed to know the dirtyness of the current dataset..
plt.figure(figsize = (25,25))
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [raw]
# In The Above HeatMap,
# Black colour shows -> non_NULL values, represented by 0, where.
# White colour shows -> NULL values, represented by 1................ in the df.isnull() dataset...

# %% [markdown]
# ### Lets see the percentage of missing values in Each column of the dataset..

# %%
# Lets see the percentage of missing values in Each column of the dataset.. 
prcnt_null = df.isnull().sum()/df.shape[0]*100

# %% [markdown]
# ### Here We Have To Get List Of The Column With 17% or More NaN values

# %%
# Creating a list of columns with 17% or more NaN values, fro the 'prcnt_null' dictionary
dropped_columns = prcnt_null[prcnt_null > 17].keys()  # we need only column name so, consider only key values..
dropped_columns
# Out:
# Index(['LotFrontage', 'Alley', 'FireplaceQu', 'PoolQC', 'Fence',
#        'MiscFeature'],
#       dtype='object')

# %% [markdown]
# ### Dropping Columns with More Missing Values..

# %%
df2_drp_clm = df.drop(columns = dropped_columns)

# %%
# Now if we check the size, we can see that, 6 columns have been dropped from the dataset of 81 columns
# i.e. there will be only 75 columns in the datasets..

df2_drp_clm.shape
# Out:
# (1460, 75)

# %%
# Now If We see the The HeatMap, it will look more cleaned...
plt.figure(figsize = (25,25))
sns.heatmap(df2_drp_clm.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### The Dataset looks Much clean, but still there is some rows that contains NaN values, so we have to drop these rows

# %% [markdown]
# ### Dropping NaN valued Rows..

# %%
df3_drp_rws = df2_drp_clm.dropna()

# %%
df3_drp_rws.shape
# Out:
# (1338, 75)

# %%
plt.figure(figsize = (25,25))
sns.heatmap(df3_drp_rws.isnull())
# Out:
# <AxesSubplot:>

# %% [raw]
# Now The HeatMap Looks FUlly Clean, here all zero values are represented with pink colour as there is no NaN values
# that are represented by 1

# %% [markdown]
# ### We can also see the difference Between Original datasets and the clean datasets.... by plotting dist plot

# %%
df3_drp_rws.select_dtypes(include = ['int64', 'float64']).columns
# Out:
# Index(['Id', 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
numeric_clm_list = ['MSSubClass', 'LotArea', 'OverallQual', 'OverallCond',
       'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
       'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
       'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
       'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
       'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
       'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
       'MoSold', 'YrSold', 'SalePrice']

# %% [markdown]
# ### Plotting Dist_plot of both Original and cleaned Dataset..

# %%
sns.distplot(df['MSSubClass'])
sns.distplot(df3_drp_rws['MSSubClass'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MSSubClass', ylabel='Density'>

# %%
plt.figure(figsize = (25,25))
for i, var in enumerate(numeric_clm_list):
    plt.subplot(9,4, i+1)
    sns.histplot(df[var], bins=20)
    sns.histplot(df3_drp_rws[var], bins=20, color = 'y')
