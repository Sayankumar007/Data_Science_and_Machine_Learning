# %% [markdown]
# # Pandas Tutorial : Writing in .csv File

# %%
import pandas as pd

# %%
# Opening a .csv File in a DataFrame
df = pd.read_csv('D:\\SAYAN SRK\\Datasets\\fortune_101.csv') 
df
# Out:
#    Unnamed: 0             Data           Unnamed: 2 Unnamed: 3    Unnamed: 4  \
# 0           0                1                    2          3             4
# 1          ID             Name             Industry  Inception       Revenue
# 2           1          Lamtone          IT Services       2009  $11,757,018
# 3           2        Stripfind   Financial Services       2010  $12,329,371
# 4           3  Canecorporation               Health       2012  $10,597,009
# 5           4         Mattouch          IT Services       2013  $14,026,934
# 6           5        Techdrill               Health       2009  $10,573,990
# 7           6         Techline               Health       2006  $13,898,119
# 8           7          Cityace               Health       2010   $9,254,614
# 9           8   Kayelectronics               Health       2009   $9,451,943
# 10          9          Ganzlax          IT Services       2011  $14,001,180
# ...

# %% [markdown]
# ### Use of header parameter..

# %%
# Using Second Row as the Header
df = pd.read_csv('D:\\SAYAN SRK\\Datasets\\fortune_101.csv', header = 1 ) 
df
# Out:
#      0                1                    2          3             4  \
# 0   ID             Name             Industry  Inception       Revenue
# 1    1          Lamtone          IT Services       2009  $11,757,018
# 2    2        Stripfind   Financial Services       2010  $12,329,371
# 3    3  Canecorporation               Health       2012  $10,597,009
# 4    4         Mattouch          IT Services       2013  $14,026,934
# 5    5        Techdrill               Health       2009  $10,573,990
# 6    6         Techline               Health       2006  $13,898,119
# 7    7          Cityace               Health       2010   $9,254,614
# 8    8   Kayelectronics               Health       2009   $9,451,943
# 9    9          Ganzlax          IT Services       2011  $14,001,180
# 10  10      Trantraxlax  Government Services       2011  $11,088,336
#
#                     5         6       7
# 0            Expenses    Profit  Growth
# 1   6,482,465 Dollars   5274553     30%
# ...

# %%
# Using Third Row as the Header
df = pd.read_csv('D:\\SAYAN SRK\\Datasets\\fortune_101.csv', header = 2 ) 
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
# NO HEADER..
df = pd.read_csv('D:\\SAYAN SRK\\Datasets\\fortune_101.csv', header = None ) 
df
# Out:
#       0                1                    2          3             4  \
# 0   NaN             Data                  NaN        NaN           NaN
# 1     0                1                    2          3             4
# 2    ID             Name             Industry  Inception       Revenue
# 3     1          Lamtone          IT Services       2009  $11,757,018
# 4     2        Stripfind   Financial Services       2010  $12,329,371
# 5     3  Canecorporation               Health       2012  $10,597,009
# 6     4         Mattouch          IT Services       2013  $14,026,934
# 7     5        Techdrill               Health       2009  $10,573,990
# 8     6         Techline               Health       2006  $13,898,119
# 9     7          Cityace               Health       2010   $9,254,614
# 10    8   Kayelectronics               Health       2009   $9,451,943
# 11    9          Ganzlax          IT Services       2011  $14,001,180
# ...

# %% [markdown]
# ### Use of prefix Parameter..

# %%
# Opening a .csv File in a DataFrame
df = pd.read_csv('D:\\SAYAN SRK\\Datasets\\fortune_10.csv') 
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %% [markdown]
# #### ```Customizing The Header```

# %%
pd.read_csv('D:\\SAYAN SRK\\Datasets\\fortune_10.csv', header = None, prefix = 'column ')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_6916\3604684806.py:1: FutureWarning: The prefix argument has been deprecated and will be removed in a future version. Use a list comprehension on the column names in the future.
#
#
#   df = pd.read_csv('D:\\SAYAN SRK\\Datasets\\fortune_10.csv', header = None, prefix = 'column ')
#    column 0         column 1             column 2   column 3      column 4  \
# 0        ID             Name             Industry  Inception       Revenue
# 1         1          Lamtone          IT Services       2009  $11,757,018
# 2         2        Stripfind   Financial Services       2010  $12,329,371
# 3         3  Canecorporation               Health       2012  $10,597,009
# 4         4         Mattouch          IT Services       2013  $14,026,934
# 5         5        Techdrill               Health       2009  $10,573,990
# 6         6         Techline               Health       2006  $13,898,119
# ...

# %%
pd.read_csv('D:\\SAYAN SRK\\Datasets\\fortune_10.csv', header = None, prefix = 'col-')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_6916\2578177593.py:1: FutureWarning: The prefix argument has been deprecated and will be removed in a future version. Use a list comprehension on the column names in the future.
#
#
#   pd.read_csv('D:\\SAYAN SRK\\Datasets\\fortune_10.csv', header = None, prefix = 'col-')
#    col-0            col-1                col-2      col-3         col-4  \
# 0     ID             Name             Industry  Inception       Revenue
# 1      1          Lamtone          IT Services       2009  $11,757,018
# 2      2        Stripfind   Financial Services       2010  $12,329,371
# 3      3  Canecorporation               Health       2012  $10,597,009
# 4      4         Mattouch          IT Services       2013  $14,026,934
# 5      5        Techdrill               Health       2009  $10,573,990
# 6      6         Techline               Health       2006  $13,898,119
# 7      7          Cityace               Health       2010   $9,254,614
# ...

# %% [markdown]
# ### Use of Names Parameter

# %%
# Customizing The Column Names.. names should be given in a List.

# %%
pd.read_csv('D:\\SAYAN SRK\\Datasets\\fortune_10.csv', names = ['A','B','C','D','E','F','G','H'])
# Out:
#      A                B                    C          D             E  \
# 0   ID             Name             Industry  Inception       Revenue
# 1    1          Lamtone          IT Services       2009  $11,757,018
# 2    2        Stripfind   Financial Services       2010  $12,329,371
# 3    3  Canecorporation               Health       2012  $10,597,009
# 4    4         Mattouch          IT Services       2013  $14,026,934
# 5    5        Techdrill               Health       2009  $10,573,990
# 6    6         Techline               Health       2006  $13,898,119
# 7    7          Cityace               Health       2010   $9,254,614
# 8    8   Kayelectronics               Health       2009   $9,451,943
# 9    9          Ganzlax          IT Services       2011  $14,001,180
# 10  10      Trantraxlax  Government Services       2011  $11,088,336
#
#                     F         G       H
# 0            Expenses    Profit  Growth
# 1   6,482,465 Dollars   5274553     30%
# ...

# %%
# If the no. of names in the list isn't equal to total colums..
# The previous columns will become the Index Automatically...
pd.read_csv('D:\\SAYAN SRK\\Datasets\\fortune_10.csv', names = ['1st','2nd','3rd','4th','5th','6th'])
# Out:
#                                     1st        2nd           3rd  \
# ID Name                        Industry  Inception       Revenue
# 1  Lamtone                  IT Services       2009  $11,757,018
# 2  Stripfind         Financial Services       2010  $12,329,371
# 3  Canecorporation               Health       2012  $10,597,009
# 4  Mattouch                 IT Services       2013  $14,026,934
# 5  Techdrill                     Health       2009  $10,573,990
# 6  Techline                      Health       2006  $13,898,119
# 7  Cityace                       Health       2010   $9,254,614
# 8  Kayelectronics                Health       2009   $9,451,943
# 9  Ganzlax                  IT Services       2011  $14,001,180
# 10 Trantraxlax      Government Services       2011  $11,088,336
#
#                                   4th       5th     6th
# ID Name                      Expenses    Profit  Growth
# 1  Lamtone          6,482,465 Dollars   5274553     30%
# ...

# %% [markdown]
# ### Use of head() Function

# %% [markdown]
# ### ```SYNTAX : df.head()      --> By default head() function displays first five rows, but we can give our desired rows in the parameter```

# %%
# Opening a .csv File in a DataFrame
df = pd.read_csv('D:\\SAYAN SRK\\Datasets\\fortune_10.csv') 
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
df.head()
# Out:
#    ID             Name            Industry  Inception       Revenue  \
# 0   1          Lamtone         IT Services       2009  $11,757,018
# 1   2        Stripfind  Financial Services       2010  $12,329,371
# 2   3  Canecorporation              Health       2012  $10,597,009
# 3   4         Mattouch         IT Services       2013  $14,026,934
# 4   5        Techdrill              Health       2009  $10,573,990
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# 4  7,435,363 Dollars   3138627     8%

# %%
df.head(1)
# Out:
#    ID     Name     Industry  Inception       Revenue           Expenses  \
# 0   1  Lamtone  IT Services       2009  $11,757,018   6,482,465 Dollars
#
#     Profit Growth
# 0  5274553    30%

# %%
df.head(7)
# Out:
#    ID             Name            Industry  Inception       Revenue  \
# 0   1          Lamtone         IT Services       2009  $11,757,018
# 1   2        Stripfind  Financial Services       2010  $12,329,371
# 2   3  Canecorporation              Health       2012  $10,597,009
# 3   4         Mattouch         IT Services       2013  $14,026,934
# 4   5        Techdrill              Health       2009  $10,573,990
# 5   6         Techline              Health       2006  $13,898,119
# 6   7          Cityace              Health       2010   $9,254,614
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# 4  7,435,363 Dollars   3138627     8%
# 5  5,470,303 Dollars   8427816    23%
# 6  6,249,498 Dollars   3005116     6%

# %% [markdown]
# ### Use of tail() Method

# %% [markdown]
# ### ```df.tail() prints the last five rows but we can give the no. of rows in the parameter```

# %%
df.tail()
# Out:
#    ID            Name             Industry  Inception       Revenue  \
# 5   6        Techline               Health       2006  $13,898,119
# 6   7         Cityace               Health       2010   $9,254,614
# 7   8  Kayelectronics               Health       2009   $9,451,943
# 8   9         Ganzlax          IT Services       2011  $14,001,180
# 9  10     Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 5  5,470,303 Dollars   8427816    23%
# 6  6,249,498 Dollars   3005116     6%
# 7  3,878,113 Dollars   5573830     4%
# 8  3,878,153 Dollars  11901180    18%
# 9  5,635,276 Dollars   5453060     7%

# %%
df.tail(7)
# Out:
#    ID            Name             Industry  Inception       Revenue  \
# 3   4        Mattouch          IT Services       2013  $14,026,934
# 4   5       Techdrill               Health       2009  $10,573,990
# 5   6        Techline               Health       2006  $13,898,119
# 6   7         Cityace               Health       2010   $9,254,614
# 7   8  Kayelectronics               Health       2009   $9,451,943
# 8   9         Ganzlax          IT Services       2011  $14,001,180
# 9  10     Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 3  7,429,377 Dollars   6597557    26%
# 4  7,435,363 Dollars   3138627     8%
# 5  5,470,303 Dollars   8427816    23%
# 6  6,249,498 Dollars   3005116     6%
# 7  3,878,113 Dollars   5573830     4%
# 8  3,878,153 Dollars  11901180    18%
# 9  5,635,276 Dollars   5453060     7%

# %%
df.tail(2)
# Out:
#    ID         Name             Industry  Inception       Revenue  \
# 8   9      Ganzlax          IT Services       2011  $14,001,180
# 9  10  Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 8  3,878,153 Dollars  11901180    18%
# 9  5,635,276 Dollars   5453060     7%

# %% [markdown]
# ### Changing The Datatype

# %%
# Changing datatype of ID and Profit from int to float.. 
df = pd.read_csv('D:\\SAYAN SRK\\Datasets\\fortune_10.csv', dtype = {'ID' : 'float64', 'Profit' : 'float64'}) 
df
# Out:
#      ID             Name             Industry  Inception       Revenue  \
# 0   1.0          Lamtone          IT Services       2009  $11,757,018
# 1   2.0        Stripfind   Financial Services       2010  $12,329,371
# 2   3.0  Canecorporation               Health       2012  $10,597,009
# 3   4.0         Mattouch          IT Services       2013  $14,026,934
# 4   5.0        Techdrill               Health       2009  $10,573,990
# 5   6.0         Techline               Health       2006  $13,898,119
# 6   7.0          Cityace               Health       2010   $9,254,614
# 7   8.0   Kayelectronics               Health       2009   $9,451,943
# 8   9.0          Ganzlax          IT Services       2011  $14,001,180
# 9  10.0      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses      Profit Growth
# 0  6,482,465 Dollars   5274553.0    30%
# 1    916,455 Dollars  11412916.0    20%
# 2  7,591,189 Dollars   3005820.0     7%
# ...

# %% [markdown]
# ### Handelling YES and NO Values

# %%
# Opening a .csv File in a DataFrame
df = pd.read_csv('D:\\SAYAN SRK\\Datasets\\fortune_102.csv') 
df
# Out:
#    ID Date             Name             Industry  Inception       Revenue  \
# 0   1  Yes          Lamtone          IT Services       2009  $11,757,018
# 1   2  Yes        Stripfind   Financial Services       2010  $12,329,371
# 2   3   No  Canecorporation               Health       2012  $10,597,009
# 3   4  Yes         Mattouch          IT Services       2013  $14,026,934
# 4   5   No        Techdrill               Health       2009  $10,573,990
# 5   6   No         Techline               Health       2006  $13,898,119
# 6   7  Yes          Cityace               Health       2010   $9,254,614
# 7   8  Yes   Kayelectronics               Health       2009   $9,451,943
# 8   9   No          Ganzlax          IT Services       2011  $14,001,180
# 9  10  Yes      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df = pd.read_csv('D:\\SAYAN SRK\\Datasets\\fortune_102.csv', true_values = ['Yes'], false_values = ['No']) 
df
# Out:
#    ID   Date             Name             Industry  Inception       Revenue  \
# 0   1   True          Lamtone          IT Services       2009  $11,757,018
# 1   2   True        Stripfind   Financial Services       2010  $12,329,371
# 2   3  False  Canecorporation               Health       2012  $10,597,009
# 3   4   True         Mattouch          IT Services       2013  $14,026,934
# 4   5  False        Techdrill               Health       2009  $10,573,990
# 5   6  False         Techline               Health       2006  $13,898,119
# 6   7   True          Cityace               Health       2010   $9,254,614
# 7   8   True   Kayelectronics               Health       2009   $9,451,943
# 8   9  False          Ganzlax          IT Services       2011  $14,001,180
# 9  10   True      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# ...
